# %% [markdown]
# ## Data acquisition via the Europeana API
#
# This notebook explains how you can extract data from the Europeana platform via its APIs. In most cases, the data that are made available via the Europeana APIs can be viewed on Europeana's public website as well. To get a sense of the type of data that are available, open the link below and have look at the metadata.
#
#
# [https://www.europeana.eu/en/item/598/9939757197402711_item_2420001](https://www.europeana.eu/en/item/598/9939757197402711_item_2420001)

# %% [markdown]
# If you want to anaylyse these data using quantitative methods, it is generally more effective to extract these values as raw data. This can be accomplished via two APIs. Europeana maintains a [Search API](https://pro.europeana.eu/page/search) and a [Record API](https://pro.europeana.eu/page/record).
#
# ## Record API
#
# The record API, firstly, enables you to retrieve the values that have been collected and created in individual records. It works with the following paramaters:
#
# * record_format: 'json' or 'rdf'
# * item_id: The full identifier of the record. This typically inculdes the identifier for the content provider.
# * profile: Value 'standard'
#
# You can view the raw data of the record you looked at earlier by clicking the URL that is generated by the cell below.

# %%
import requests
import re
from os.path import join
import json

from credentials import api_key
base_url_record = 'https://api.europeana.eu/record/v2/'
record_format = 'json'
item_id = '598/9939757197402711_item_2420001'
profile = 'standard'

api_call = f'{base_url_record}{item_id}.{record_format}?profile={profile}&wskey={api_key}'

print(api_call)
# Out:
# https://api.europeana.eu/record/v2/598/9939757197402711_item_2420001.json?profile=standard&wskey=ineternates

# %% [markdown]
# ### Exercise
#
# Try to obtain raw data about another object in Europeana. You can work with one of the objects below, for example.
#
# * https://www.europeana.eu/en/item/598/9939757142102711_item_2709295
# * https://www.europeana.eu/item/598/9939757129002711_item_935820
#
# The code that was given exports the the data in the JSON format. Also try to view the data in RDF/XML format.

# %% [markdown]
# The cells below give an impression of the kinds of values that are available in Europeana records. Note that the code only shows you a small fraction of the data values that are actually available.

# %%
base_url_record = 'https://api.europeana.eu/record/v2/'
record_format = 'json'
item_id = '598/9939757129002711_item_935820'
profile = 'standard'

api_call = f'{base_url_record}{item_id}.{record_format}?profile={profile}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
# Out:
# https://api.europeana.eu/record/v2/598/9939757129002711_item_935820.json?profile=standard&wskey=ineternates

# %%
agents = dict()

for agent in api_data['object']['agents']:
    if 'prefLabel' in agent:
        label = agent['prefLabel']['en'][0]
        about = agent['about']
        agents[about] = label

for agent in agents:
    print(f'{agent}\n{agents[agent]}\n')
    
places = dict()

for place in api_data['object']['places']:

    if 'en' in place['prefLabel']:
        label = place['prefLabel']['en'][0]
    else:
        label = ''
        
    about = place['about']
    places[about] = label
        


for place in places:
    print(f'{place}\n{places[place]}\n')
    
        
for proxy in api_data['object']['proxies']:

    if 'year' in proxy:
        print('Year: ' + proxy['year']['def'][0])
    print('Language: ' + proxy['dcLanguage']['def'][0])
    
    if 'dcDescription' in proxy:
        if 'en' in proxy['dcDescription']:
            for note in proxy['dcDescription']['en']:
                print(note)
                
    if 'dctermsExtent' in proxy:
        if 'en' in proxy['dctermsExtent']:
            for note in proxy['dcDescription']['en']:
                print(note)
# Out:
# http://www.wikidata.org/entity/Q892143
# Bonaventura Vulcanius
#
#
#
# http://data.europeana.eu/place/85
# France
#
# http://vocab.getty.edu/tgn/1000070
# France
#
# https://sws.geonames.org/2751772/
#
#
# https://sws.geonames.org/11874022/
#
#
# Year: 1425
# Language: lat
# Language: lat
# decorated initials, coloured symbols in the tables
# handwritten, littera textualis
# 17 lines, written space varies
# Binding: Medieval binding, contemporary (so-called belt book).
# Description (Senguerdius & 1716): http://hdl.handle.net/1887.1/item:290399
# Description (Molhuysen 1910): http://hdl.handle.net/1887.1/item:3151050
# Description (Catalogus compendiarius 1932): http://hdl.handle.net/1887.1/item:491294
# Also described by MMDC and A.W. Byvanckgenootschap (database RKD, The Hague).
# Restored (report available), 1986
# decorated initials, coloured symbols in the tables
# handwritten, littera textualis
# 17 lines, written space varies
# Binding: Medieval binding, contemporary (so-called belt book).
# Description (Senguerdius & 1716): http://hdl.handle.net/1887.1/item:290399
# Description (Molhuysen 1910): http://hdl.handle.net/1887.1/item:3151050
# Description (Catalogus compendiarius 1932): http://hdl.handle.net/1887.1/item:491294
# Also described by MMDC and A.W. Byvanckgenootschap (database RKD, The Hague).
# Restored (report available), 1986

# %% [markdown]
# ## Search API
#
# The search API can be used to select records with specific properties in the Europeana database. Te query below selects all the items from Leiden University that are part of the [ARMA collection](https://www.medieval-reads.eu/home).

# %%
base_url = 'https://api.europeana.eu/record/v2/search.json?'
profile= 'standard' 
qf= 'Leiden%20University%20Libraries'
query='middle%20ages'
rows=100
start=1

api_call = f'{base_url}profile={profile}&qf={qf}&query={query}&rows={rows}&start={start}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
    if len(api_data)>0:
        print(f"{api_data['totalResults']} results")
# Out:
# https://api.europeana.eu/record/v2/search.json?profile=standard&qf=Leiden%20University%20Libraries&query=middle%20ages&rows=100&start=1&wskey=ineternates
# 610 results

# %% [markdown]
# To experiment with the Search API, change the value of the query parameter below.

# %%
base_url = 'https://api.europeana.eu/record/v2/search.json?'
profile= 'standard' 
query='alchemy'
rows=100
start=1

api_call = f'{base_url}profile={profile}&query={query}&rows={rows}&start={start}&wskey={api_key}'
print(api_call)

response = requests.get(api_call)

if response:
    api_data = response.json()
    if len(api_data)>0:
        print(f"{api_data['totalResults']} results")
# Out:
# https://api.europeana.eu/record/v2/search.json?profile=standard&query=alchemy&rows=100&start=1&wskey=ineternates
# 2201 results

# %%
if len(api_data)>0:
    for item in api_data['items']:
        print(item['guid'], end = '\n\n')
# Out:
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000012917000200?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200271/BibliographicResource_3000058904832?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200271/BibliographicResource_3000058904829?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/283/2746_C?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/92093/BibliographicResource_1000086140428?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2064114/Museu_ProvidedCHO_Digitales_Kunst__und_Kulturarchiv_D_sseldorf_854849?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/qj5u2zua?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200519/ark__12148_btv1b90613892?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/02301/urn_imss_indepth_100013?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2059218/data_sounds_IT_DDS0000007420004900?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200519/ark__12148_btv1b9062097w?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/x4aejvj7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/ejaq84uz?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/fausjuh8?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200235/bitstream_1880_49900_1_UofCPress_MarionNicholl_2013_pdf?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/vjryfk2u?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200519/ark__12148_btv1b90622891?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/gmrhr6t6?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/q55a5s7u?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/cxj2cvdj?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200519/ark__12148_btv1b9061313x?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/nx5jbjad?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/b2znqjd9?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/wfhs8rvg?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/p9hezhkg?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/2051908/data_euscreenXL_ina_CPF86631796?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/prq9vy28?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/bjxym2j7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200519/ark__12148_btv1b9062026t?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_DWVSI7YIPIIGOC42KTWYPUN2DZUSW5YP?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/90901/nd_ark__59851_bmc7w6z0?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/xxdvhur5?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/ahjfd99w?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/9200579/d4kd6uuk?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_N3QZJT33D4O7ZYDATOFZR7QIRK4ENBD7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_NXZYBMTEV2LUYTTG5AMWME6HHRARU2B7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_Q6FHQKTNHUSLXIWEXIW4CL3OJZ57ZP2S?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_QYGSHRP5U2KQUUQ444QEFSU5DF7MMB2O?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_SBY23ITLUT7EHS6Z6G4CGFUCEXPJAKDS?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_YOZWHRWZJYMKKWSVCDBMXXWOJPSNNT5V?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_HCXSSPO7UEMWD7SIXSW5K5RUCY24QNH5?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_Q2CTHPVVNWOORBGFIRSYFICNGBO77Q7S?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_Q5WW7GNCVP36I6TFXAUVQ52EZWR23BRK?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_QLS7UX6MXQV6DNGTAMTAG7NP3TH7ZHBQ?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_QXS5OEIE3GK2BA44OCS6BFBTDDBSXQJT?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_RH6QNR32TJDY5HUPPC54QXMJYA4JZC52?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_THCXCW5LKQYTMG5ZKC3JL3QVBHDMIQ2H?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_TMFIKTN6UKGGF2PS4UVPIKEVZ2JBBVAI?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_TOOECRROW2WCTX6FTT5Q745J23FZLQ5L?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_VQSYQTXWK2IR43YWENNUEPQLXTGBKB3S?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_WFU7ZC74DDI3ZF46JBVL5KE5KVOZBDWZ?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_ZBZ6Z36BNBLVG2YHZBHQMUEGPKEYISPT?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_BUXCHIWY5YH7RUP7UPIATTKJZVLBE7DB?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_CEYLZBV4TGWK5ARMWLDEDWZRDRZR3VZX?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_DQ5TD6ATZJUI3PYQCB6BAY5NJ2VTFPW6?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_DYWKB4ZLCFTXJVRBDU3X7CAE6P4P7ZRP?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_FGEC3OCYRKOR5XBUDARA2IMXYCWIOPSN?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_G2MGEPCIVODYIEUDDXP55Q2NXUQ5Z3SK?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_GC26KHHUOXUWJFLARD5RAMJW5GVOQG4N?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_HL53CK677YG4MZSJRHVNQPI7DDFAJNRU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_L7ALLSTE7BVAXIAQNP63W6QJPX6SOSKM?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_LDT4RYAKEK2FGRLQLDYJKMCTEYFANNHP?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_OVFTEU5JBMCR6RAF3GLHTVRQUROK47SF?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_PIA3YYZNT6WHH2IHIYEFQNBJYPH5J6SU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_2R74BQCNZPH5DG6YE4KHT4ILPBMRQUM7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_2Z3GKZN5VXBHTYN6ETJZZQBE2WH4IVUW?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_3USQGS4SDT7DNRNG7PLB3JPVPN6TCGVW?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_3V23YAGXLTOZQCZUNBB7WPOU6FAUQASY?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_4RZR22VOUS266TMVW7XJGJIC7LQXH6M7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_4TAYRTJFNGQ2MNXNUAKA7MK2JATLVBIO?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_4TQTFFSEPXIALWCPYINBBNR23CNKAJ2D?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_57JTXA7INSSNEKRG3S42UU745FJSOZ5B?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_5K3QHEBRWM2MNPMMHT5NFE7VJW32GWAU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_5RLJYF7RWAU3PH3RNHTPUP3UZ4BTJUJF?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_7YE3NAFPABVJ4FZU7VYETY6DD6DO3ZLU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_A3ERS5OLOJSB7ELL7AGBJ22ZOMN556EW?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_AT4R7X6KJTGB4R2RYGGPEG7THO6ZCAON?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_B3LGHIDOJE4MQ2GN4GW2NG454ULFRMMK?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_BBFSNUD5K27HGVII7IOV5SEJFQZT6PAB?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_DGUAHKFIDGG6KMVMI5TPBO6RFDGPMDD2?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_GEKKI7BNZ6JXXG3XP6HSEJJQBYDST4SH?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_GWQXW7I6LAQ6WKH6MOMEJDZFV5R43TYO?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_OF2PH57YRFZJSSZUU7B4CHM5OXQQDHDQ?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/463/item_XUTXTZDZQM3Q44EUX6C4OUL3CB4NCQVH?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_Q7EXDIGDBWNUBYF7FOMRYMVAL6Q5A4Z2?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_QLQICZWRGHGSVRIR2QVNHGLNA5RCNH7F?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_S76VDNG6UOGXJ3GSTSJ2Z546C2UTLVLU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_Y326VXUDAVEGSRRHYPS5J4SWULDHKXGY?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_Y6WKGZDCO2PMB3AWVSXTVJMKJO6R5XO4?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_EL4LKAXS6IMF75KCG5EBAQJH26GU5MBU?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_EZ5LBPSMGVKGMHZKEGQ7PPFLJUKCRT4O?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_JOO2OKJKB5AMOIFLUAEOLMJ4HFCQMVH7?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/437/item_NGLRYMNR4A54EDPDLKFVO3KYSB73E6E2?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_5CWP3BH3SCFR3NYATRXXVDMWNKR4JV3W?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_7RXATEN6YFGROY72SRNIOJJOHMFILVDD?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_AFB2H4I32J2EN7R4OJ3R5DLO5BYOY2AD?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_AUSB55QQ4EFJTFP4UVFPI3NNZAL7R7EM?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/440/item_JKQ7D4URPF34VITUAZ4SPCKV3PKI7Y5F?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_BLBZ6N54D75T5GMPKJAQWJ5DUBVVIEKA?utm_source=api&utm_medium=api&utm_campaign=ineternates
#
# https://www.europeana.eu/item/188/item_CEU537V2PEM5IIPSJ4AT6CO33PI4EVUH?utm_source=api&utm_medium=api&utm_campaign=ineternates
